# %%
import pandas as pd
import numpy as np
import random

# %%
user_profile = pd.read_csv("/Users/abhavgoel/Desktop/FlipStyle/User data/user_profile.csv")
user_profile
# Out:
#      UserID  Gender  Age       Region  Pincode  BodyType SizeGenerallyBought
# 0         1   Other   34  West Bengal   841052     Curvy                  XL
# 1         2  Female   55  West Bengal   486474  Athletic                  XS
# 2         3   Other   37       Kerala   440717      Slim                  XL
# 3         4    Male   34     Nagaland   840677   Average                   M
# 4         5    Male   35     Nagaland   683974     Curvy                   M
# ..      ...     ...  ...          ...      ...       ...                 ...
# 495     496  Female   36       Punjab   296780   Average                  XS
# 496     497  Female   49       Sikkim   652844  Athletic                   M
# 497     498  Female   22    Karnataka   564993      Slim                   S
# 498     499   Other   25  Uttarakhand   236826      Slim                 XXL
# 499     500  Female   47  Maharashtra   676433     Curvy                  XS
#
# [500 rows x 7 columns]

# %%
browsing_history = pd.read_csv("/Users/abhavgoel/Desktop/FlipStyle/User data/browsing_history.csv")
browsing_history #(per user 5 entries)
# Out:
#       UserID                 Date  TimeSpentSeconds   Device  VisitFrequency  \
# 0          1  2021-01-01 00:00:00                39   Tablet              18
# 1          1  2021-01-01 01:00:00               299   Mobile              11
# 2          1  2021-01-01 02:00:00               485   Mobile               8
# 3          1  2021-01-01 03:00:00               318   Tablet              16
# 4          1  2021-01-01 04:00:00               166  Desktop              10
# ...      ...                  ...               ...      ...             ...
# 2495     500  2021-04-14 23:00:00               416  Desktop               8
# 2496     500  2021-04-15 00:00:00               281   Mobile               2
# 2497     500  2021-04-15 01:00:00               141   Mobile              13
# 2498     500  2021-04-15 02:00:00               401  Desktop               8
# 2499     500  2021-04-15 03:00:00               473  Desktop              14
#
#      ProductType ProductDescription
# ...

# %%
purchase_history = pd.read_csv("/Users/abhavgoel/Desktop/FlipStyle/User data/purchase_history.csv")
purchase_history
# Out:
#       UserID        Date  OrderNumber ShippingAddress  AmountSpent  \
# 0          1  2021-01-01            1           City1   167.008530
# 1          1  2021-01-02            2           City2   490.796811
# 2          1  2021-01-03            3           City3   135.139598
# 3          1  2021-01-04            4           City4   104.338844
# 4          1  2021-01-05            5           City5   458.648753
# ...      ...         ...          ...             ...          ...
# 2495     500  2027-11-01         2496        City2496   319.362239
# 2496     500  2027-11-02         2497        City2497   456.402829
# 2497     500  2027-11-03         2498        City2498   489.672228
# 2498     500  2027-11-04         2499        City2499   381.811949
# 2499     500  2027-11-05         2500        City2500   238.468048
#
#       PaymentMode  SaleStatus      ItemsPurchased  DiscountAmount  \
# 0            Cash       False          Bucket Hat       28.190413
# ...

# %%
random.seed(36)
user_id = random.randint(1,500)
user_id
# Out:
# 169

# %%
user_data = purchase_history.query(f"UserID == {user_id}").iloc
# user_gender = user_data['Gender']
# user_age = user_data['Age']
# user_region = user_data['Region']
# user_body_type = user_data['BodyType']
user_data[4]
# Out:
# UserID                      169
# Date                 2023-04-25
# OrderNumber                 845
# ShippingAddress         City845
# AmountSpent          128.413857
# PaymentMode                Cash
# SaleStatus                False
# ItemsPurchased      Moisturizer
# DiscountAmount        26.177371
# ReturnStatus       Not Returned
# ReturnReason                NaN
# Name: 844, dtype: object

# %%
purchase_history=[]
for data in user_data:
    purchase_history.append(data['ItemsPurchased'])

# %%
purchase_history
# Out:
# ['Hiking Backpack', 'Blush', 'Denim Shorts', 'Knit Gloves', 'Moisturizer']

# %%
print(rs)
# Out:
# [" V-Neck T-Shirt", " Stiletto Heels", " Track Pants", " Fleece Hoodie", " Turtleneck Sweater"]
